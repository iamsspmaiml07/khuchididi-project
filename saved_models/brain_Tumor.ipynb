# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../dataset/Brain Tumor.csv")

# %%
data = data.head(5000)

# %%
data.tail()
# Out:
#      Patient ID  Age  Gender Tumor Type  Tumor Size (cm) Tumor Location  \
# 4995     P04996   37    Male     Benign             7.67      Occipital
# 4996     P04997   81  Female  Malignant             1.51        Frontal
# 4997     P04998   33  Female  Malignant             3.31       Parietal
# 4998     P04999   68  Female  Malignant             7.79       Temporal
# 4999     P05000   54    Male  Malignant             3.51       Parietal
#
#      MRI Findings  WBC Count (x10^3/uL)  Lymphocyte (%)  PCR Test  \
# 4995        Clear                 14.08           45.70  Positive
# 4996        Clear                 12.74           25.44  Positive
# 4997        Clear                 11.51           41.84  Negative
# 4998        Clear                  8.23           42.32  Positive
# 4999        Clear                  6.52           32.85  Positive
#
#      COVID Severity  Oxygen Sat (%) Symptoms (Headache) Symptoms (Seizures)  \
# 4995         Severe           79.73                 Yes                 Yes
# 4996            NaN           98.20                 Yes                  No
# 4997         Severe           77.54                 Yes                 Yes
# 4998         Severe           95.89                  No                  No
# 4999           Mild           95.34                  No                  No
#
#      Treatment Type        Outcome
# 4995   Radiotherapy  Complications
# 4996   Radiotherapy       Deceased
# 4997    Observation       Deceased
# 4998   Radiotherapy       Deceased
# 4999   Radiotherapy       Deceased

# %%
data.shape
# Out:
# (5000, 16)

# %%
# Drop unnecessary columns

brain = data.drop(columns=['Patient ID'])

# %%
brain
# Out:
#       Age  Gender Tumor Type  Tumor Size (cm) Tumor Location MRI Findings  \
# 0      69  Female     Benign             5.01        Frontal      Present
# 1      32  Female  Malignant             3.52       Temporal      Present
# 2      78  Female     Benign             8.24       Temporal        Clear
# 3      38    Male     Benign             9.58       Parietal        Clear
# 4      41    Male  Malignant             1.40       Parietal        Clear
# ...   ...     ...        ...              ...            ...          ...
# 4995   37    Male     Benign             7.67      Occipital        Clear
# 4996   81  Female  Malignant             1.51        Frontal        Clear
# 4997   33  Female  Malignant             3.31       Parietal        Clear
# 4998   68  Female  Malignant             7.79       Temporal        Clear
# 4999   54    Male  Malignant             3.51       Parietal        Clear
#
#       WBC Count (x10^3/uL)  Lymphocyte (%)  PCR Test COVID Severity  \
# 0                     4.32           32.53  Positive           Mild
# 1                     5.86           39.84  Negative       Moderate
# 2                     8.86           34.18  Negative            NaN
# 3                     6.77           16.38  Positive         Severe
# 4                     4.90           18.76  Positive           Mild
# ...                    ...             ...       ...            ...
# 4995                 14.08           45.70  Positive         Severe
# 4996                 12.74           25.44  Positive            NaN
# 4997                 11.51           41.84  Negative         Severe
# 4998                  8.23           42.32  Positive         Severe
# 4999                  6.52           32.85  Positive           Mild
#
#       Oxygen Sat (%) Symptoms (Headache) Symptoms (Seizures) Treatment Type  \
# 0              96.67                  No                  No       Steroids
# 1              85.72                 Yes                 Yes    Observation
# 2              89.67                 Yes                 Yes       Steroids
# 3              89.30                 Yes                 Yes   Radiotherapy
# 4              92.98                  No                  No       Steroids
# ...              ...                 ...                 ...            ...
# 4995           79.73                 Yes                 Yes   Radiotherapy
# 4996           98.20                 Yes                  No   Radiotherapy
# 4997           77.54                 Yes                 Yes    Observation
# 4998           95.89                  No                  No   Radiotherapy
# 4999           95.34                  No                  No   Radiotherapy
#
#             Outcome
# 0          Deceased
# 1     Complications
# 2         Recovered
# 3     Complications
# 4         Recovered
# ...             ...
# 4995  Complications
# 4996       Deceased
# 4997       Deceased
# 4998       Deceased
# 4999       Deceased
#
# [5000 rows x 15 columns]

# %%
brain.isna().sum()
# Out:
# Age                        0
# Gender                     0
# Tumor Type                 0
# Tumor Size (cm)            0
# Tumor Location             0
# MRI Findings               0
# WBC Count (x10^3/uL)       0
# Lymphocyte (%)             0
# PCR Test                   0
# COVID Severity          1293
# Oxygen Sat (%)             0
# Symptoms (Headache)        0
# Symptoms (Seizures)        0
# Treatment Type             0
# Outcome                    0
# dtype: int64

# %%
# Handle missing values by filling with the mode (most common value)
brain['COVID Severity'].fillna(brain['COVID Severity'].mode()[0], inplace=True)
# Out:
# C:\Users\sujit maity\AppData\Local\Temp\ipykernel_13344\811725398.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   brain['COVID Severity'].fillna(brain['COVID Severity'].mode()[0], inplace=True)

# %%
brain.isna().sum()
# Out:
# Age                     0
# Gender                  0
# Tumor Type              0
# Tumor Size (cm)         0
# Tumor Location          0
# MRI Findings            0
# WBC Count (x10^3/uL)    0
# Lymphocyte (%)          0
# PCR Test                0
# COVID Severity          0
# Oxygen Sat (%)          0
# Symptoms (Headache)     0
# Symptoms (Seizures)     0
# Treatment Type          0
# Outcome                 0
# dtype: int64

# %%
brain.describe()
# Out:
#                Age  Tumor Size (cm)  WBC Count (x10^3/uL)  Lymphocyte (%)  \
# count  5000.000000      5000.000000           5000.000000     5000.000000
# mean     51.014600         5.271336              9.429616       30.115402
# std      19.310613         2.755098              3.168393       11.573689
# min      18.000000         0.500000              4.010000       10.010000
# 25%      34.000000         2.840000              6.680000       19.967500
# 50%      51.000000         5.320000              9.400000       30.355000
# 75%      68.000000         7.602500             12.160000       40.120000
# max      84.000000        10.000000             15.000000       49.980000
#
#        Oxygen Sat (%)
# count     5000.000000
# mean        87.476602
# std          7.200221
# min         75.000000
# 25%         81.157500
# 50%         87.540000
# 75%         93.662500
# max         99.990000

# %%
brain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   5000 non-null   int64
#  1   Gender                5000 non-null   object
#  2   Tumor Type            5000 non-null   object
#  3   Tumor Size (cm)       5000 non-null   float64
#  4   Tumor Location        5000 non-null   object
#  5   MRI Findings          5000 non-null   object
#  6   WBC Count (x10^3/uL)  5000 non-null   float64
#  7   Lymphocyte (%)        5000 non-null   float64
#  8   PCR Test              5000 non-null   object
#  9   COVID Severity        5000 non-null   object
#  10  Oxygen Sat (%)        5000 non-null   float64
#  11  Symptoms (Headache)   5000 non-null   object
#  12  Symptoms (Seizures)   5000 non-null   object
#  13  Treatment Type        5000 non-null   object
#  14  Outcome               5000 non-null   object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 586.1+ KB

# %%
# Encode categorical variables
categorical_columns = brain.select_dtypes(include='object').columns
label_encoders = {}

# %%
label_encoders = {}
for column in categorical_columns:
    label_encoder = LabelEncoder()
    brain[column] = label_encoder.fit_transform(brain[column])
    label_encoders[column] = label_encoder

# %%
brain.head()
# Out:
#    Age  Gender  Tumor Type  Tumor Size (cm)  Tumor Location  MRI Findings  \
# 0   69       0           0             5.01               0             1
# 1   32       0           1             3.52               3             1
# 2   78       0           0             8.24               3             0
# 3   38       1           0             9.58               2             0
# 4   41       1           1             1.40               2             0
#
#    WBC Count (x10^3/uL)  Lymphocyte (%)  PCR Test  COVID Severity  \
# 0                  4.32           32.53         1               0
# 1                  5.86           39.84         0               1
# 2                  8.86           34.18         0               1
# 3                  6.77           16.38         1               2
# 4                  4.90           18.76         1               0
#
#    Oxygen Sat (%)  Symptoms (Headache)  Symptoms (Seizures)  Treatment Type  \
# 0           96.67                    0                    0               3
# 1           85.72                    1                    1               1
# 2           89.67                    1                    1               3
# 3           89.30                    1                    1               2
# 4           92.98                    0                    0               3
#
#    Outcome
# 0        1
# 1        0
# 2        2
# 3        0
# 4        2

# %%
brain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   5000 non-null   int64
#  1   Gender                5000 non-null   int32
#  2   Tumor Type            5000 non-null   int32
#  3   Tumor Size (cm)       5000 non-null   float64
#  4   Tumor Location        5000 non-null   int32
#  5   MRI Findings          5000 non-null   int32
#  6   WBC Count (x10^3/uL)  5000 non-null   float64
#  7   Lymphocyte (%)        5000 non-null   float64
#  8   PCR Test              5000 non-null   int32
#  9   COVID Severity        5000 non-null   int32
#  10  Oxygen Sat (%)        5000 non-null   float64
#  11  Symptoms (Headache)   5000 non-null   int32
#  12  Symptoms (Seizures)   5000 non-null   int32
#  13  Treatment Type        5000 non-null   int32
#  14  Outcome               5000 non-null   int32
# dtypes: float64(4), int32(10), int64(1)
# memory usage: 390.8 KB

# %%
# Split data into features and target
X = brain.drop(columns=['Outcome'])
y = brain['Outcome']

# %%
# Standardize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Build and train the Random Forest Classifier
model = RandomForestClassifier(random_state=42, n_estimators=100)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make predictions and evaluate the model
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)
print("-----------------------")
print(f"Accuracy: {accuracy}")
print("-----------------------")
print("Classification Report:")
print(report)
# Out:
# -----------------------
# Accuracy: 0.316
# -----------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.32      0.37      0.34       345
#            1       0.32      0.29      0.30       334
#            2       0.31      0.28      0.29       321
#
#     accuracy                           0.32      1000
#    macro avg       0.32      0.31      0.31      1000
# weighted avg       0.32      0.32      0.31      1000

# %%
# Evaluate the model
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train)
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  1.0

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test)
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.316

# %%
# Example prediction
input_data = (78,0,0,8.24,3,0,8.86,34.18,0,2,89.67,1,1,3)  # Update with real values
import numpy as np
# Changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# Reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

# Using the trained classifier directly for prediction
prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
    print('The person does not have a brain tumor')
else:
    print('The person has a brain tumor')
# Out:
# [2]
# The person has a brain tumor

# %%
import pickle

# Save model as .sav
filename = "brains.sav"
pickle.dump(model, open(filename, "wb"))
